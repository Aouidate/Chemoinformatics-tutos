# %% [markdown]
# # ADN T002 ~ Molecular Descriptors and Fingerprints

# %% [markdown]
# Authors:
#
# * Adnane Aouidate, 2022, Structural Bioinformatics and Chemoinformatics, Institute of Organic and Analytical Chemistry (ICOA), Orléans, France.
# * Update , 2023, Ait Melloul Faculty of Applied Sciences, Ibn Zohr University, Agadir, Morocco.
#
# ## Aim of this talktorial
#
# In the current tutorial we will learn how to use python combined with Rdkit in order to calculate different molecular descriptors descriptors, using in built *rdkit* functions and also third party software like *Mordred*.
#
# as a definition : a **Molecular Descriptor or MD** “… the final result of a logical and mathematical procedure that transforms chemical information of a molecule, such as structural features, into useful numbers or the result of standardized experiments.
#
# Utility :
#
# They can be used in Molecular similarity to compare molecules (and/or their properties), so it can help us to identify new molecules with desired properties and biological activity
#
# ## Molecular descriptors
# *Similarity can be assessed in many different ways depending on the application (see J. Med. Chem. (2014), 57, 3186-3204</a>):*
#
# * 1D molecular descriptor: Solubility, logP, molecular weight, melting point.
#     * Global descriptor: only one value represents the whole molecule
#     * Usually do not contain enough information to be applied to machine learning (ML)
#     * Can be added to 2D fingerprints to improve molecular encoding for ML
# * 2D molecular descriptors: Molecular graphs, paths, fragments, atom environments
#     * Detailed representation of individual parts of the molecule
#     * Contains many features/bits per molecule called fingerprints
#     * Very often used in similarity search and ML
# * 3D molecular descriptors: Shape, stereochemistry
#     * Less robust than 2D representations because of molecule flexibility (what is the "right" conformation of a molecule?) Biological similarity
#     * Biological fingerprint, e.g. individual bits represent bioactivity measure against different targets
#     * Independent of molecular structure
#     * Requires experimental (or predicted) data

# %%
import pandas as pd
import numpy as np
from rdkit import Chem,DataStructs
from rdkit.Chem import AllChem, Descriptors, MACCSkeys
from rdkit.Chem.Draw import IPythonConsole
from mordred import Calculator, descriptors

# %% [markdown]
# Let's first read the sdf file

# %%
file = 'data-test.sdf'
mols = []
for m in Chem.SDMolSupplier(file):
    if m is not None:
        mols.append(m)

# %%
len(mols)
# Out:
# 50

# %% [markdown]
# ### Molecular descriptors using *Rdkit*

# %%
desc = []

for m in mols :
    desc.append([Descriptors.MolLogP(m),
    Descriptors.HeavyAtomCount(m),
    Descriptors.MolMR(m),
    Descriptors.MolWt(m),
    Descriptors.NumHAcceptors(m),
    Descriptors.NumHDonors(m)])
columns = ['logp', 'HAC', 'MMR', 'MW', 'NHA', 'NHB']
desc = pd.DataFrame(desc, columns= columns)

# %%
desc
# Out:
#        logp  HAC       MMR        MW  NHA  NHB
# 0   2.14360   12   47.4680   156.188    2    0
# 1   0.39950   10   35.3720   138.174    4    0
# 2  -0.26630    6   25.5104    86.158    0    1
# 3  -0.48910   17   68.2684   236.403    0    2
# 4   2.78300   14   57.0440   180.210    2    0
# 5   2.16120   25   95.9625   344.519    2    2
# 6   2.16120   25   95.9625   344.519    2    2
# 7  -2.93810   56  186.3958   804.880   18   11
# 8  -5.11390   67  219.0292   967.021   23   14
# 9  -2.93810   56  186.3958   804.880   18   11
# 10 -2.93810   56  186.3958   804.880   18   11
# 11 -2.93810   56  186.3958   804.880   18   11
# 12 -5.11390   67  219.0292   967.021   23   14
# 13 -5.11390   67  219.0292   967.021   23   14
# 14 -2.93810   56  186.3958   804.880   18   11
# 15 -2.93810   56  186.3958   804.880   18   11
# 16 -2.93810   56  186.3958   804.880   18   11
# 17 -2.93810   56  186.3958   804.880   18   11
# 18 -2.93810   56  186.3958   804.880   18   11
# 19 -2.93810   56  186.3958   804.880   18   11
# 20 -2.93810   56  186.3958   804.880   18   11
# 21 -2.93810   56  186.3958   804.880   18   11
# 22 -5.11390   67  219.0292   967.021   23   14
# 23 -5.11390   67  219.0292   967.021   23   14
# 24 -0.76230   45  153.7624   642.739   13    8
# 25 -4.08470   66  217.6394   951.022   22   13
# 26 -4.47480   65  213.0224   936.995   22   13
# 27 -4.47480   65  213.0224   936.995   22   13
# 28 -4.47480   65  213.0224   936.995   22   13
# 29 -5.11390   67  219.0292   967.021   23   14
# 30 -5.11390   67  219.0292   967.021   23   14
# 31 -7.28970   78  251.6626  1129.162   28   17
# 32 -5.11390   67  219.0292   967.021   23   14
# 33 -2.93810   56  186.3958   804.880   18   11
# 34  1.82360   20   70.6766   280.320    5    2
# 35  1.78160   26   95.1424   362.466    5    3
# 36  1.55760   26   95.0484   360.450    5    3
# 37  3.21270   29  108.3024   402.531    5    3
# 38  1.76580   26   94.0486   358.434    5    2
# 39  2.53270   26   88.5558   358.390    6    1
# 40  1.20459   19   67.7948   261.297    4    1
# 41  1.97540   26  107.3334   358.614    0    2
# 42  2.41960   18   66.7220   246.306    3    0
# 43  2.45180   18   65.8530   248.322    3    0
# 44  1.39040   19   68.1118   262.305    4    1
# 45  1.59310   18   70.4577   248.390    1    1
# 46  0.92540   15   53.1042   231.293    4    0
# 47  1.51230   13   45.7110   182.219    3    0
# 48 -2.09446   27   94.5902   375.361    9    4
# 49  2.40170   11   44.2360   152.237    1    0

# %% [markdown]
# ### Molecular descriptors using *Mordred*

# %%
df = pd.read_csv("./databases/acetylcholinesterase_Ki_pKi_bioactivity_data_curated.csv", index_col="molecule_chembl_id")

# %% [markdown]
# Let's first read the database that we got from the the jupyter notebook ADN_T000 in this series of notebooks

# %%
df.head()
# Out:
#                    units       Ki  \
# molecule_chembl_id
# CHEMBL11805           nM    0.104
# CHEMBL208599          nM    0.026
# CHEMBL60745           nM    1.630
# CHEMBL95              nM  151.000
# CHEMBL173309          nM   12.200
#
#                                                                smiles  \
# molecule_chembl_id
# CHEMBL11805         COc1ccccc1CN(C)CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)...
# CHEMBL208599               CCC1=CC2Cc3nc4cc(Cl)ccc4c(N)c3[C@@H](C1)C2
# CHEMBL60745                             CC[N+](C)(C)c1cccc(O)c1.[Br-]
# CHEMBL95                                      Nc1c2c(nc3ccccc13)CCCC2
# CHEMBL173309        CCN(CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCCCCN(CC)C...
#
#                           pKi
# molecule_chembl_id
# CHEMBL11805          9.982967
# CHEMBL208599        10.585027
# CHEMBL60745          8.787812
# CHEMBL95             6.821023
# CHEMBL173309         7.913640

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472 entries, 0 to 471
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   molecule_chembl_id  472 non-null    object
#  1   units               472 non-null    object
#  2   Ki                  472 non-null    float64
#  3   smiles              472 non-null    object
#  4   pKi                 472 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 18.6+ KB

# %% [markdown]
# Here, we will get all molecules as mols rdkit objects

# %%
mols = [Chem.MolFromSmiles(smi) for smi in df.smiles]

# %% [markdown]
# ### Create descriptor calculato

# %%
Calc = Calculator(descriptors, ignore_3D= True)

# %%
len(Calc.descriptors)
# Out:
# 1613

# %% [markdown]
# # Calculate descriptors and store them in a dataframe

# %%
df1 = Calc.pandas(mols)
# Out:
#   0%|                                           | 1/472 [00:01<14:28,  1.84s/it]
# /Users/adnane/opt/anaconda3/envs/ADN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   1%|▎                                          | 4/472 [00:02<09:56,  1.28s/it]
# /Users/adnane/opt/anaconda3/envs/ADN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   3%|█▏                                        | 13/472 [00:06<04:06,  1.86it/s]
# /Users/adnane/opt/anaconda3/envs/ADN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   8%|███▌                                      | 40/472 [00:09<01:13,  5.89it/s]
# /Users/adnane/opt/anaconda3/envs/ADN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   9%|███▋                                      | 42/472 [00:09<01:07,  6.35it/s]
# /Users/adnane/opt/anaconda3/envs/ADN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#  20%|████████▌                                 | 96/472 [00:30<04:50,  1.29it/s]
# /Users/adnane/opt/anaconda3/envs/ADN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#  23%|█████████▍                               | 109/472 [00:31<01:31,  3.96it/s]
# /Users/adnane/opt/anaconda3/envs/ADN/lib/python3.7/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|█████████████████████████████████████████| 472/472 [02:31<00:00,  3.11it/s]

# %%
df1.head()
# Out:
#          ABC      ABCGG  nAcid  nBase                             SpAbs_A  \
# 0  35.142811  24.264889      0      2                           60.122409
# 1  16.987142  12.790496      0      0                           27.467293
# 2   8.850899   8.508709      1      1  multiple fragments (SpAbs_A/SpAbs)
# 3  11.968445   9.625522      0      0                           20.264831
# 4  36.338245  25.499176      0      2                           63.382841
#
#                               SpMax_A                              SpDiam_A  \
# 0                            2.279705                               4.55941
# 1                            2.533089                              5.066178
# 2  multiple fragments (SpMax_A/SpMax)  multiple fragments (SpDiam_A/SpDiam)
# 3                            2.459954                              4.919908
# 4                            2.287195                               4.57439
#
#                              SpAD_A                             SpMAD_A  \
# 0                         60.122409                             1.25255
# 1                         27.467293                            1.307966
# 2  multiple fragments (SpAD_A/SpAD)  multiple fragments (SpMAD_A/SpMAD)
# 3                         20.264831                            1.350989
# 4                         63.382841                            1.267657
#
#                               LogEE_A  ...      SRW10     TSRW10          MW  \
# 0                            4.737539  ...  10.238852  84.598254  666.508407
# 1                            4.015374  ...  10.293467  55.839709  298.123676
# 2  multiple fragments (LogEE_A/LogEE)  ...   9.303375  43.773162  245.041526
# 3                             3.67295  ...   9.827416  47.796305  198.115698
# 4                            4.776866  ...  10.283053  86.794615  694.539707
#
#         AMW       WPath WPol  Zagreb1  Zagreb2  \
# 0  5.846565       14630   63    218.0    238.0
# 1  7.453092         842   39    120.0    147.0
# 2  8.449708  1200000190   16     58.0     65.0
# 3  6.831576         326   25     82.0     99.0
# 4  5.787831       16085   67    226.0    248.0
#
#                                          mZagreb1   mZagreb2
# 0                                       16.611111  11.361111
# 1                                            6.25   4.472222
# 2  divide by zero encountered in power (mZagreb1)   2.708333
# 3                                        3.805556   3.277778
# 4                                       17.111111  12.027778
#
# [5 rows x 1613 columns]

# %% [markdown]
# ### Let's set the index cas cid of the molecules

# %%
df1.set_index(df.index, inplace=True)

# %%
df1.head()
# Out:
#                           ABC      ABCGG  nAcid  nBase  \
# molecule_chembl_id
# CHEMBL11805         35.142811  24.264889      0      2
# CHEMBL208599        16.987142  12.790496      0      0
# CHEMBL60745          8.850899   8.508709      1      1
# CHEMBL95            11.968445   9.625522      0      0
# CHEMBL173309        36.338245  25.499176      0      2
#
#                                                SpAbs_A  \
# molecule_chembl_id
# CHEMBL11805                                  60.122409
# CHEMBL208599                                 27.467293
# CHEMBL60745         multiple fragments (SpAbs_A/SpAbs)
# CHEMBL95                                     20.264831
# CHEMBL173309                                 63.382841
#
#                                                SpMax_A  \
# molecule_chembl_id
# CHEMBL11805                                   2.279705
# CHEMBL208599                                  2.533089
# CHEMBL60745         multiple fragments (SpMax_A/SpMax)
# CHEMBL95                                      2.459954
# CHEMBL173309                                  2.287195
#
#                                                 SpDiam_A  \
# molecule_chembl_id
# CHEMBL11805                                      4.55941
# CHEMBL208599                                    5.066178
# CHEMBL60745         multiple fragments (SpDiam_A/SpDiam)
# CHEMBL95                                        4.919908
# CHEMBL173309                                     4.57439
#
#                                               SpAD_A  \
# molecule_chembl_id
# CHEMBL11805                                60.122409
# CHEMBL208599                               27.467293
# CHEMBL60745         multiple fragments (SpAD_A/SpAD)
# CHEMBL95                                   20.264831
# CHEMBL173309                               63.382841
#
#                                                SpMAD_A  \
# molecule_chembl_id
# CHEMBL11805                                    1.25255
# CHEMBL208599                                  1.307966
# CHEMBL60745         multiple fragments (SpMAD_A/SpMAD)
# CHEMBL95                                      1.350989
# CHEMBL173309                                  1.267657
#
#                                                LogEE_A  ...      SRW10  \
# molecule_chembl_id                                      ...
# CHEMBL11805                                   4.737539  ...  10.238852
# CHEMBL208599                                  4.015374  ...  10.293467
# CHEMBL60745         multiple fragments (LogEE_A/LogEE)  ...   9.303375
# CHEMBL95                                       3.67295  ...   9.827416
# CHEMBL173309                                  4.776866  ...  10.283053
#
#                        TSRW10          MW       AMW       WPath WPol  Zagreb1  \
# molecule_chembl_id
# CHEMBL11805         84.598254  666.508407  5.846565       14630   63    218.0
# CHEMBL208599        55.839709  298.123676  7.453092         842   39    120.0
# CHEMBL60745         43.773162  245.041526  8.449708  1200000190   16     58.0
# CHEMBL95            47.796305  198.115698  6.831576         326   25     82.0
# CHEMBL173309        86.794615  694.539707  5.787831       16085   67    226.0
#
#                     Zagreb2                                        mZagreb1  \
# molecule_chembl_id
# CHEMBL11805           238.0                                       16.611111
# CHEMBL208599          147.0                                            6.25
# CHEMBL60745            65.0  divide by zero encountered in power (mZagreb1)
# CHEMBL95               99.0                                        3.805556
# CHEMBL173309          248.0                                       17.111111
#
#                      mZagreb2
# molecule_chembl_id
# CHEMBL11805         11.361111
# CHEMBL208599         4.472222
# CHEMBL60745          2.708333
# CHEMBL95             3.277778
# CHEMBL173309        12.027778
#
# [5 rows x 1613 columns]

# %% [markdown]
# ### Check for none values

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %%
# Out:
# ABC         float64
# ABCGG       float64
# nAcid         int64
# nBase         int64
# SpAbs_A      object
#              ...
# WPol          int64
# Zagreb1     float64
# Zagreb2     float64
# mZagreb1     object
# mZagreb2    float64
# Length: 1613, dtype: object

# %% [markdown]
# ### Molecular fingerprints
# Will be calculated soon !!

# %%
# def get_fingerprints(smiles,method = 'MCCS'):
    
#     for mol in Chem.SDMolSupplier(file):
#         if mol is not None:
            
#             if method == 'MCCS':
#                 return (fp == np.asanyarray(MACCSkeys.GenMACCSKeys(mol)))

# #             if method == 'morgan2':
# #                 return pd.DataFrame(AllChem.GetHashedAtomPairFingerprintAsBitVect(mol, nBits=2048))
