# %% [markdown]
# # ADN_T004. QSAR models
#
# Authors:
# * Adnane Aouidate, (2019-2020), Computer Aided Drug Discovery Center, Shenzhen Institute of Advanced Technology(SIAT), Shenzhen, China.
# * Adnane Aouidate, (2021-2022), Structural Bioinformatics and Chemoinformatics, Institute of Organic and Analytical Chemistry (ICOA), Orléans, France.
# * Update , 2023, Ait Melloul Faculty of Applied Sciences, Ibn Zohr University, Agadir, Morocco,
#
# ### Aim of this tutorial
#
# In this tutorial, you will learn how to build and validate a Quantitative Structure-Activity Relationship (QSAR) model using data from the ChEMBL (Chemical Entities of Biological Interest) database.
#
# QSAR models are **useful techniques in drug discovery research** and are frequently utilized in the hit-to-lead and lead optimization steps by drug discovery researchers.
#
# QSAR **is a technique that allows researchers to identify new drug candidates** by predicting which compounds are likely to be active against a target molecule.
#
# In this tutorial, you will learn how to use the Python scikit-learn library in order to preprocess and curate your data, and then use it in machine learning-based QSAR models.
#
# **Let's get started!**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mordred import descriptors, Calculator
from rdkit import Chem
from rdkit.Chem import AllChem
print(np.__version__)
# Out:
# 1.21.5

# %%
df = pd.read_csv('./databases/acetylcholinesterase_pKi_mordredMD.csv', index_col=0)

# %%
df.dropna(how= 'any', inplace=True)

# %%
df
# Out:
#                           ABC      ABCGG  nAcid  nBase  nAromAtom  nAromBond  \
# molecule_chembl_id
# CHEMBL11805         35.142811  24.264889      0      2         12         12
# CHEMBL208599        16.987142  12.790496      0      0         10         11
# CHEMBL60745          8.850899   8.508709      1      1          6          6
# CHEMBL95            11.968445   9.625522      0      0         10         11
# CHEMBL173309        36.338245  25.499176      0      2         12         12
# ...                       ...        ...    ...    ...        ...        ...
# CHEMBL5220695       20.523035  16.217858      0      1          6          6
# CHEMBL5219239       21.299091  16.948723      0      1          6          6
# CHEMBL5218804       17.706179  13.397976      0      0         12         12
# CHEMBL5219425       12.915350  11.452675      1      1          0          0
# CHEMBL193996        14.211085  11.347741      0      1          6          6
#
#                     nAtom  nHeavyAtom  nSpiro  nBridgehead  ...      SRW10  \
# molecule_chembl_id                                          ...
# CHEMBL11805           114          48       0            0  ...  10.238852
# CHEMBL208599           40          21       0            2  ...  10.293467
# CHEMBL60745            29          13       0            0  ...   9.303375
# CHEMBL95               29          15       0            0  ...   9.827416
# CHEMBL173309          120          50       0            0  ...  10.283053
# ...                   ...         ...     ...          ...  ...        ...
# CHEMBL5220695          58          27       0            0  ...   9.925102
# CHEMBL5219239          61          28       0            0  ...  10.015431
# CHEMBL5218804          44          23       0            0  ...   9.899530
# CHEMBL5219425          43          18       0            2  ...   9.909817
# CHEMBL193996           36          18       0            2  ...   9.776847
#
#                        TSRW10          MW       AMW       WPath  WPol  \
# molecule_chembl_id
# CHEMBL11805         84.598254  666.508407  5.846565       14630    63
# CHEMBL208599        55.839709  298.123676  7.453092         842    39
# CHEMBL60745         43.773162  245.041526  8.449708  1200000190    16
# CHEMBL95            47.796305  198.115698  6.831576         326    25
# CHEMBL173309        86.794615  694.539707  5.787831       16085    67
# ...                       ...         ...       ...         ...   ...
# CHEMBL5220695       61.461191  377.231456  6.503991        2240    35
# CHEMBL5219239       62.768394  391.247107  6.413887        2463    38
# CHEMBL5218804       57.005714  311.152144  7.071640        1376    33
# CHEMBL5219425       51.182410  368.096076  8.560374  1700000520    25
# CHEMBL193996        51.137963  246.136828  6.837134         656    23
#
#                     Zagreb1  Zagreb2   mZagreb2        pKi
# molecule_chembl_id
# CHEMBL11805           218.0    238.0  11.361111   9.982967
# CHEMBL208599          120.0    147.0   4.472222  10.585027
# CHEMBL60745            58.0     65.0   2.708333   8.787812
# CHEMBL95               82.0     99.0   3.277778   6.821023
# CHEMBL173309          226.0    248.0  12.027778   7.913640
# ...                     ...      ...        ...        ...
# CHEMBL5220695         132.0    145.0   5.930556   6.920819
# CHEMBL5219239         138.0    153.0   6.125000   6.769551
# CHEMBL5218804         116.0    133.0   5.222222   9.578396
# CHEMBL5219425          88.0    103.0   3.847222   5.455932
# CHEMBL193996           94.0    108.0   3.944444   6.000000
#
# [472 rows x 1027 columns]

# %%
y = df['pKi']

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# ABC          float64
# ABCGG        float64
# nAcid          int64
# nBase          int64
# nAromAtom      int64
#               ...
# WPol           int64
# Zagreb1      float64
# Zagreb2      float64
# mZagreb2     float64
# pKi          float64
# Length: 1027, dtype: object

# %%
df_indices = df.index
data_columuns = df.columns

# %% [markdown]
# ### Convert values to mumerics

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler

# %%
Scaler = StandardScaler().fit(df)
df1 = Scaler.transform(df)
df1 = pd.DataFrame(data= df1, index=df_indices, columns= data_columuns)
df1
# Out:
#                          ABC     ABCGG     nAcid     nBase  nAromAtom  \
# molecule_chembl_id
# CHEMBL11805         1.708479  1.735525 -0.382930  1.753151  -0.193073
# CHEMBL208599       -0.704518 -0.846431 -0.382930 -0.991417  -0.507315
# CHEMBL60745        -1.785873 -1.809915  1.406605  0.380867  -1.135801
# CHEMBL95           -1.371532 -1.558610 -0.382930 -0.991417  -0.507315
# CHEMBL173309        1.867360  2.013263 -0.382930  1.753151  -0.193073
# ...                      ...       ...       ...       ...        ...
# CHEMBL5220695      -0.234576 -0.075210 -0.382930  0.380867  -1.135801
# CHEMBL5219239      -0.131434  0.089249 -0.382930  0.380867  -1.135801
# CHEMBL5218804      -0.608953 -0.709737 -0.382930 -0.991417  -0.193073
# CHEMBL5219425      -1.245683 -1.147466  1.406605  0.380867  -2.078529
# CHEMBL193996       -1.073472 -1.171079 -0.382930  0.380867  -1.135801
#
#                     nAromBond     nAtom  nHeavyAtom    nSpiro  nBridgehead  \
# molecule_chembl_id
# CHEMBL11805         -0.257035  2.868298    2.015231 -0.089721    -0.163233
# CHEMBL208599        -0.400440 -0.775018   -0.847242 -0.089721     5.340041
# CHEMBL60745         -1.117465 -1.316592   -1.695382 -0.089721    -0.163233
# CHEMBL95            -0.400440 -1.316592   -1.483347 -0.089721    -0.163233
# CHEMBL173309        -0.257035  3.163702    2.227266 -0.089721    -0.163233
# ...                       ...       ...         ...       ...          ...
# CHEMBL5220695       -1.117465  0.111194   -0.211137 -0.089721    -0.163233
# CHEMBL5219239       -1.117465  0.258896   -0.105119 -0.089721    -0.163233
# CHEMBL5218804       -0.257035 -0.578082   -0.635207 -0.089721    -0.163233
# CHEMBL5219425       -1.977894 -0.627316   -1.165294 -0.089721     5.340041
# CHEMBL193996        -1.117465 -0.971954   -1.165294 -0.089721     5.340041
#
#                     ...     SRW10    TSRW10        MW       AMW     WPath  \
# molecule_chembl_id  ...
# CHEMBL11805         ...  0.178133  1.212683  1.942580 -1.141241 -0.299641
# CHEMBL208599        ...  0.285876 -0.945155 -0.905936 -0.163119 -0.299645
# CHEMBL60745         ... -1.667368 -1.850543 -1.316391  0.443663  0.040745
# CHEMBL95            ... -0.633544 -1.548675 -1.679243 -0.541524 -0.299645
# CHEMBL173309        ...  0.265333  1.377482  2.159331 -1.177000 -0.299641
# ...                 ...       ...       ...       ...       ...       ...
# CHEMBL5220695       ... -0.440830 -0.523359 -0.294239 -0.740972 -0.299645
# CHEMBL5219239       ... -0.262629 -0.425275 -0.185864 -0.795831 -0.299645
# CHEMBL5218804       ... -0.491279 -0.857666 -0.805194 -0.395363 -0.299645
# CHEMBL5219425       ... -0.470984 -1.294605 -0.364878  0.511041  0.182574
# CHEMBL193996        ... -0.733307 -1.297940 -1.307922 -0.538140 -0.299645
#
#                         WPol   Zagreb1   Zagreb2  mZagreb2       pKi
# molecule_chembl_id
# CHEMBL11805         1.009158  1.338423  1.017473  2.352085  1.870065
# CHEMBL208599       -0.341633 -0.558565 -0.425854 -0.921218  2.191256
# CHEMBL60745        -1.636141 -1.758700 -1.726434 -1.759342  1.232467
# CHEMBL95           -1.129594 -1.294131 -1.187169 -1.488766  0.183211
# CHEMBL173309        1.234290  1.493279  1.176080  2.668856  0.766107
# ...                      ...       ...       ...       ...       ...
# CHEMBL5220695      -0.566765 -0.326281 -0.457575 -0.228281  0.236450
# CHEMBL5219239      -0.397916 -0.210138 -0.330690 -0.135889  0.155751
# CHEMBL5218804      -0.679330 -0.635993 -0.647904 -0.564850  1.654232
# CHEMBL5219425      -1.129594 -1.177989 -1.123726 -1.218191 -0.545047
# CHEMBL193996       -1.242160 -1.061847 -1.044423 -1.171995 -0.254794
#
# [472 rows x 1027 columns]

# %%
df1.to_csv('./databases/acetylcholinesterase_mordred_scaled_descriptors.csv', index=True)

# %%
from tqdm.auto import tqdm

# %% [markdown]
# ## Remove features that display high correlation with other features

# %%
correlated_features_1 = set()
corr_matrix = df1.corr()

# %%
corr_matrix
# Out:
#                 ABC     ABCGG     nAcid     nBase  nAromAtom  nAromBond  \
# ABC        1.000000  0.975893 -0.017485  0.156459   0.734489   0.732963
# ABCGG      0.975893  1.000000 -0.020316  0.150692   0.664477   0.658610
# nAcid     -0.017485 -0.020316  1.000000  0.468423   0.049378   0.039674
# nBase      0.156459  0.150692  0.468423  1.000000   0.067140   0.044946
# nAromAtom  0.734489  0.664477  0.049378  0.067140   1.000000   0.996773
# ...             ...       ...       ...       ...        ...        ...
# WPol       0.958953  0.959700 -0.064457  0.075135   0.711422   0.710969
# Zagreb1    0.993935  0.976799 -0.038783  0.132486   0.746545   0.745032
# Zagreb2    0.978759  0.966753 -0.059341  0.107642   0.750792   0.749837
# mZagreb2   0.979102  0.954461  0.017197  0.196819   0.665723   0.663627
# pKi        0.330915  0.282831 -0.116094 -0.151362   0.296372   0.312154
#
#               nAtom  nHeavyAtom    nSpiro  nBridgehead  ...     SRW10  \
# ABC        0.926278    0.993147  0.112880     0.095730  ...  0.791155
# ABCGG      0.895024    0.969510  0.180522     0.088568  ...  0.806022
# nAcid      0.040153    0.051392  0.034454     0.062684  ... -0.102307
# nBase      0.249803    0.200010  0.034172     0.046170  ...  0.053970
# nAromAtom  0.533746    0.707204  0.000802    -0.024188  ...  0.715977
# ...             ...         ...       ...          ...  ...       ...
# WPol       0.843061    0.934784  0.182161     0.128635  ...  0.884904
# Zagreb1    0.894446    0.977376  0.139934     0.107885  ...  0.843405
# Zagreb2    0.859312    0.953987  0.166101     0.116339  ...  0.879422
# mZagreb2   0.962763    0.991499  0.078950     0.078617  ...  0.682087
# pKi        0.342081    0.316321 -0.060370     0.109281  ...  0.264728
#
#              TSRW10        MW       AMW     WPath      WPol   Zagreb1  \
# ABC        0.873177  0.921575 -0.277788  0.180991  0.958953  0.993935
# ABCGG      0.884833  0.900923 -0.249467  0.227039  0.959700  0.976799
# nAcid     -0.054238  0.298560  0.400702  0.632917 -0.064457 -0.038783
# nBase      0.193255  0.292760 -0.006248  0.260757  0.075135  0.132486
# nAromAtom  0.642245  0.662290 -0.019054  0.036271  0.711422  0.746545
# ...             ...       ...       ...       ...       ...       ...
# WPol       0.864715  0.854810 -0.227681  0.136115  1.000000  0.980536
# Zagreb1    0.890066  0.900943 -0.256871  0.162405  0.980536  1.000000
# Zagreb2    0.896116  0.872244 -0.240430  0.143242  0.990781  0.995180
# mZagreb2   0.828639  0.926827 -0.324511  0.218753  0.904882  0.954042
# pKi        0.267840  0.269521 -0.211021 -0.054328  0.302159  0.327956
#
#             Zagreb2  mZagreb2       pKi
# ABC        0.978759  0.979102  0.330915
# ABCGG      0.966753  0.954461  0.282831
# nAcid     -0.059341  0.017197 -0.116094
# nBase      0.107642  0.196819 -0.151362
# nAromAtom  0.750792  0.665723  0.296372
# ...             ...       ...       ...
# WPol       0.990781  0.904882  0.302159
# Zagreb1    0.995180  0.954042  0.327956
# Zagreb2    1.000000  0.924220  0.321681
# mZagreb2   0.924220  1.000000  0.316342
# pKi        0.321681  0.316342  1.000000
#
# [1027 rows x 1027 columns]

# %%
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) > 0.8:
            colname = corr_matrix.columns[i]
            correlated_features_1.add(colname)

# %%
correlated_features_1
# Out:
# {'AATS0are',
#  'AATS0d',
#  'AATS0m',
#  'AATS0p',
#  'AATS0pe',
#  'AATS0se',
#  'AATS0v',
#  'AATS1are',
#  'AATS1d',
#  'AATS1dv',
#  'AATS1i',
#  'AATS1m',
#  'AATS1p',
#  'AATS1pe',
#  'AATS1se',
#  'AATS1v',
#  'AATS2Z',
#  'AATS2are',
#  'AATS2d',
#  'AATS2dv',
#  'AATS2i',
#  'AATS2m',
#  'AATS2p',
#  'AATS2pe',
#  'AATS2se',
#  'AATS2v',
#  'AATS3Z',
#  'AATS3are',
#  'AATS3d',
#  'AATS3dv',
#  'AATS3m',
#  'AATS3p',
#  'AATS3pe',
#  'AATS3se',
#  'AATS3v',
#  'AATS4Z',
#  'AATS4are',
#  'AATS4d',
#  'AATS4dv',
#  'AATS4m',
#  'AATS4p',
#  'AATS4pe',
#  'AATS4se',
#  'AATS4v',
#  'AATS5Z',
#  'AATS5are',
#  'AATS5d',
#  'AATS5dv',
#  'AATS5m',
#  'AATS5p',
#  'AATS5pe',
#  'AATS5se',
#  'AATS5v',
#  'AATSC0Z',
#  'AATSC0are',
#  'AATSC0d',
#  'AATSC0dv',
#  'AATSC0i',
#  'AATSC0m',
#  'AATSC0p',
#  'AATSC0pe',
#  'AATSC0se',
#  'AATSC1Z',
#  'AATSC1are',
#  'AATSC1i',
#  'AATSC1m',
#  'AATSC1p',
#  'AATSC1pe',
#  'AATSC1se',
#  'AATSC1v',
#  'AATSC2Z',
#  'AATSC2are',
#  'AATSC2c',
#  'AATSC2d',
#  'AATSC2dv',
#  'AATSC2i',
#  'AATSC2m',
#  'AATSC2p',
#  'AATSC2pe',
#  'AATSC2se',
#  'AATSC2v',
#  'AATSC3Z',
#  'AATSC3are',
#  'AATSC3c',
#  'AATSC3d',
#  'AATSC3dv',
#  'AATSC3i',
#  'AATSC3m',
#  'AATSC3p',
#  'AATSC3pe',
#  'AATSC3se',
#  'AATSC3v',
#  'AATSC4Z',
#  'AATSC4are',
#  'AATSC4c',
#  'AATSC4d',
#  'AATSC4dv',
#  'AATSC4i',
#  'AATSC4m',
#  'AATSC4p',
#  'AATSC4pe',
#  'AATSC4se',
#  'AATSC4v',
#  'AATSC5are',
#  'AATSC5m',
#  'AATSC5pe',
#  'ABCGG',
#  'AMW',
#  'ATS0are',
#  'ATS0d',
#  'ATS0dv',
#  'ATS0i',
#  'ATS0m',
#  'ATS0p',
#  'ATS0pe',
#  'ATS0se',
#  'ATS0v',
#  'ATS1Z',
#  'ATS1are',
#  'ATS1d',
#  'ATS1dv',
#  'ATS1i',
#  'ATS1m',
#  'ATS1p',
#  'ATS1pe',
#  'ATS1se',
#  'ATS1v',
#  'ATS2Z',
#  'ATS2are',
#  'ATS2d',
#  'ATS2dv',
#  'ATS2i',
#  'ATS2m',
#  'ATS2p',
#  'ATS2pe',
#  'ATS2se',
#  'ATS2v',
#  'ATS3Z',
#  'ATS3are',
#  'ATS3d',
#  'ATS3dv',
#  'ATS3i',
#  'ATS3m',
#  'ATS3p',
#  'ATS3pe',
#  'ATS3se',
#  'ATS3v',
#  'ATS4Z',
#  'ATS4are',
#  'ATS4d',
#  'ATS4dv',
#  'ATS4i',
#  'ATS4m',
#  'ATS4p',
#  'ATS4pe',
#  'ATS4se',
#  'ATS4v',
#  'ATS5Z',
#  'ATS5are',
#  'ATS5d',
#  'ATS5dv',
#  'ATS5i',
#  'ATS5m',
#  'ATS5p',
#  'ATS5pe',
#  'ATS5se',
#  'ATS5v',
#  'ATS6Z',
#  'ATS6are',
#  'ATS6d',
#  'ATS6dv',
#  'ATS6i',
#  'ATS6m',
#  'ATS6p',
#  'ATS6pe',
#  'ATS6se',
#  'ATS6v',
#  'ATS7Z',
#  'ATS7are',
#  'ATS7d',
#  'ATS7dv',
#  'ATS7i',
#  'ATS7m',
#  'ATS7p',
#  'ATS7pe',
#  'ATS7se',
#  'ATS7v',
#  'ATS8Z',
#  'ATS8are',
#  'ATS8d',
#  'ATS8dv',
#  'ATS8i',
#  'ATS8m',
#  'ATS8p',
#  'ATS8pe',
#  'ATS8se',
#  'ATS8v',
#  'ATSC0Z',
#  'ATSC0are',
#  'ATSC0d',
#  'ATSC0dv',
#  'ATSC0i',
#  'ATSC0m',
#  'ATSC0p',
#  'ATSC0pe',
#  'ATSC0se',
#  'ATSC0v',
#  'ATSC1are',
#  'ATSC1d',
#  'ATSC1dv',
#  'ATSC1i',
#  'ATSC1m',
#  'ATSC1p',
#  'ATSC1pe',
#  'ATSC2are',
#  'ATSC2m',
#  'ATSC2p',
#  'ATSC2pe',
#  'ATSC3are',
#  'ATSC3m',
#  'ATSC3p',
#  'ATSC3pe',
#  'ATSC3v',
#  'ATSC4are',
#  'ATSC4m',
#  'ATSC4p',
#  'ATSC4pe',
#  'ATSC5are',
#  'ATSC5i',
#  'ATSC5m',
#  'ATSC5p',
#  'ATSC5pe',
#  'ATSC5v',
#  'ATSC6are',
#  'ATSC6i',
#  'ATSC6m',
#  'ATSC6p',
#  'ATSC6pe',
#  'ATSC6v',
#  'ATSC7are',
#  'ATSC7i',
#  'ATSC7m',
#  'ATSC7p',
#  'ATSC7pe',
#  'ATSC8are',
#  'ATSC8i',
#  'ATSC8m',
#  'ATSC8p',
#  'ATSC8pe',
#  'AXp-1d',
#  'AXp-2d',
#  'AXp-2dv',
#  'AXp-3d',
#  'AXp-3dv',
#  'AXp-4d',
#  'AXp-4dv',
#  'AXp-5d',
#  'AXp-5dv',
#  'AXp-6d',
#  'AXp-6dv',
#  'BIC0',
#  'BIC1',
#  'BIC2',
#  'BIC3',
#  'BIC4',
#  'BIC5',
#  'BertzCT',
#  'C1SP1',
#  'C2SP2',
#  'C2SP3',
#  'CIC0',
#  'CIC1',
#  'CIC2',
#  'CIC3',
#  'CIC4',
#  'CIC5',
#  'Diameter',
#  'FCSP3',
#  'FilterItLogS',
#  'GATS1are',
#  'GATS1c',
#  'GATS1i',
#  'GATS1m',
#  'GATS1p',
#  'GATS1pe',
#  'GATS1v',
#  'GATS2Z',
#  'GATS2are',
#  'GATS2i',
#  'GATS2m',
#  'GATS2p',
#  'GATS2pe',
#  'GATS2v',
#  'GATS3Z',
#  'GATS3are',
#  'GATS3m',
#  'GATS3pe',
#  'GATS3v',
#  'GATS4Z',
#  'GATS4are',
#  'GATS4d',
#  'GATS4dv',
#  'GATS4m',
#  'GATS4pe',
#  'GATS4v',
#  'GATS5Z',
#  'GATS5are',
#  'GATS5d',
#  'GATS5i',
#  'GATS5m',
#  'GATS5p',
#  'GATS5pe',
#  'GATS5v',
#  'GGI1',
#  'GGI10',
#  'GGI2',
#  'GGI3',
#  'GGI4',
#  'GGI5',
#  'GGI6',
#  'GGI7',
#  'GGI8',
#  'GGI9',
#  'HybRatio',
#  'IC2',
#  'IC3',
#  'IC4',
#  'IC5',
#  'JGT10',
#  'Kier1',
#  'Kier2',
#  'Kier3',
#  'LabuteASA',
#  'MATS1Z',
#  'MATS1are',
#  'MATS1d',
#  'MATS1dv',
#  'MATS1i',
#  'MATS1m',
#  'MATS1p',
#  'MATS1pe',
#  'MATS1se',
#  'MATS1v',
#  'MATS2Z',
#  'MATS2are',
#  'MATS2c',
#  'MATS2d',
#  'MATS2dv',
#  'MATS2i',
#  'MATS2m',
#  'MATS2p',
#  'MATS2pe',
#  'MATS2se',
#  'MATS2v',
#  'MATS3Z',
#  'MATS3are',
#  'MATS3c',
#  'MATS3d',
#  'MATS3dv',
#  'MATS3i',
#  'MATS3m',
#  'MATS3p',
#  'MATS3pe',
#  'MATS3se',
#  'MATS3v',
#  'MATS4are',
#  'MATS4c',
#  'MATS4d',
#  'MATS4dv',
#  'MATS4i',
#  'MATS4m',
#  'MATS4p',
#  'MATS4pe',
#  'MATS4se',
#  'MATS4v',
#  'MATS5Z',
#  'MATS5are',
#  'MATS5c',
#  'MATS5d',
#  'MATS5dv',
#  'MATS5i',
#  'MATS5m',
#  'MATS5p',
#  'MATS5pe',
#  'MATS5se',
#  'MATS5v',
#  'MIC0',
#  'MIC1',
#  'MIC2',
#  'MIC3',
#  'MIC4',
#  'MIC5',
#  'MPC10',
#  'MPC2',
#  'MPC3',
#  'MPC4',
#  'MPC5',
#  'MPC6',
#  'MPC7',
#  'MPC8',
#  'MPC9',
#  'MW',
#  'MWC01',
#  'MWC02',
#  'MWC03',
#  'MWC04',
#  'MWC05',
#  'MWC06',
#  'MWC07',
#  'MWC08',
#  'MWC09',
#  'MWC10',
#  'MZ',
#  'Mare',
#  'Mi',
#  'Mm',
#  'Mp',
#  'Mpe',
#  'Mse',
#  'Mv',
#  'NaaCH',
#  'NdO',
#  'NdsssP',
#  'NsCl',
#  'NsF',
#  'NssCH2',
#  'NssssB',
#  'NssssSi',
#  'NtCH',
#  'NtN',
#  'NtsC',
#  'PEOE_VSA1',
#  'PEOE_VSA7',
#  'PetitjeanIndex',
#  'Radius',
#  'RotRatio',
#  'SIC0',
#  'SIC2',
#  'SIC3',
#  'SIC4',
#  'SIC5',
#  'SMR',
#  'SMR_VSA1',
#  'SMR_VSA2',
#  'SMR_VSA5',
#  'SMR_VSA7',
#  'SRW02',
#  'SRW04',
#  'SRW05',
#  'SRW06',
#  'SRW07',
#  'SRW08',
#  'SRW09',
#  'SRW10',
#  'SZ',
#  'SaaCH',
#  'SaaN',
#  'SaaNH',
#  'SaaO',
#  'SaaS',
#  'SaaaC',
#  'SaasN',
#  'Sare',
#  'SdCH2',
#  'SdO',
#  'SdS',
#  'SddsN',
#  'SddssS',
#  'SdsCH',
#  'SdsN',
#  'SdsssP',
#  'Si',
#  'SlogP_VSA1',
#  'SlogP_VSA11',
#  'SlogP_VSA2',
#  'SlogP_VSA5',
#  'SlogP_VSA6',
#  'SlogP_VSA8',
#  'Sm',
#  'Sp',
#  'Spe',
#  'SsBr',
#  'SsCH3',
#  'SsCl',
#  'SsF',
#  'SsNH2',
#  'SsOH',
#  'Sse',
#  'SssCH2',
#  'SssNH',
#  'SssO',
#  'SssS',
#  'SsssN',
#  'SssssB',
#  'SssssC',
#  'SssssN',
#  'SssssSi',
#  'StCH',
#  'StN',
#  'StsC',
#  'Sv',
#  'TIC0',
#  'TIC1',
#  'TIC2',
#  'TIC3',
#  'TIC4',
#  'TIC5',
#  'TMPC10',
#  'TMWC10',
#  'TSRW10',
#  'TopoPSA',
#  'TopoShapeIndex',
#  'TpiPC10',
#  'VAdjMat',
#  'VMcGowan',
#  'VSA_EState3',
#  'VSA_EState6',
#  'VSA_EState8',
#  'WPath',
#  'WPol',
#  'Xc-4dv',
#  'Xc-5dv',
#  'Xc-6d',
#  'Xc-6dv',
#  'Xch-4dv',
#  'Xch-5dv',
#  'Xch-6dv',
#  'Xch-7d',
#  'Xch-7dv',
#  'Xp-0dv',
#  'Xp-1d',
#  'Xp-1dv',
#  'Xp-2d',
#  'Xp-2dv',
#  'Xp-3d',
#  'Xp-3dv',
#  'Xp-4d',
#  'Xp-4dv',
#  'Xp-5d',
#  'Xp-5dv',
#  'Xp-6d',
#  'Xp-6dv',
#  'Xp-7d',
#  'Xp-7dv',
#  'Xpc-4d',
#  'Xpc-4dv',
#  'Xpc-5d',
#  'Xpc-5dv',
#  'Xpc-6d',
#  'Xpc-6dv',
#  'ZMIC0',
#  'ZMIC1',
#  'ZMIC2',
#  'ZMIC3',
#  'ZMIC4',
#  'ZMIC5',
#  'Zagreb1',
#  'Zagreb2',
#  'apol',
#  'bpol',
#  'fragCpx',
#  'mZagreb2',
#  'n10FHRing',
#  'n10FaHRing',
#  'n10FaRing',
#  'n11FAHRing',
#  'n11FARing',
#  'n11FHRing',
#  'n12FAHRing',
#  'n12FARing',
#  'n12FHRing',
#  'n4AHRing',
#  'n4ARing',
#  'n4HRing',
#  'n4Ring',
#  'n5AHRing',
#  'n5ARing',
#  'n5HRing',
#  'n5Ring',
#  'n5aHRing',
#  'n6ARing',
#  'n6HRing',
#  'n6Ring',
#  'n6aHRing',
#  'n6aRing',
#  'n7AHRing',
#  'n7ARing',
#  'n7HRing',
#  'n8ARing',
#  'n8FAHRing',
#  'n8FARing',
#  'n8FHRing',
#  'n9FARing',
#  'n9FaHRing',
#  'nARing',
#  'nAromBond',
#  'nAtom',
#  'nBonds',
#  'nBondsA',
#  'nBondsKD',
#  'nBondsKS',
#  'nBondsM',
#  'nBondsO',
#  'nBondsS',
#  'nBr',
#  'nC',
#  'nFAHRing',
#  'nFHRing',
#  'nFaHRing',
#  'nG12AHRing',
#  'nG12ARing',
#  'nG12FAHRing',
#  'nG12FARing',
#  'nG12FHRing',
#  'nG12HRing',
#  'nH',
#  'nHeavyAtom',
#  'nRing',
#  'nRot',
#  'naRing',
#  'piPC1',
#  'piPC10',
#  'piPC2',
#  'piPC3',
#  'piPC4',
#  'piPC5',
#  'piPC6',
#  'piPC7',
#  'piPC8',
#  'piPC9'}

# %%
## Remove correlated features.
def remove_correlated_features(features, data):
    for x in features:
        data.drop(x, axis=1, inplace=True)
    return data

# %%
remove_correlated_features(correlated_features_1, df1)
# Out:
#                          ABC     nAcid     nBase  nAromAtom    nSpiro  \
# molecule_chembl_id
# CHEMBL11805         1.708479 -0.382930  1.753151  -0.193073 -0.089721
# CHEMBL208599       -0.704518 -0.382930 -0.991417  -0.507315 -0.089721
# CHEMBL60745        -1.785873  1.406605  0.380867  -1.135801 -0.089721
# CHEMBL95           -1.371532 -0.382930 -0.991417  -0.507315 -0.089721
# CHEMBL173309        1.867360 -0.382930  1.753151  -0.193073 -0.089721
# ...                      ...       ...       ...        ...       ...
# CHEMBL5220695      -0.234576 -0.382930  0.380867  -1.135801 -0.089721
# CHEMBL5219239      -0.131434 -0.382930  0.380867  -1.135801 -0.089721
# CHEMBL5218804      -0.608953 -0.382930 -0.991417  -0.193073 -0.089721
# CHEMBL5219425      -1.245683  1.406605  0.380867  -2.078529 -0.089721
# CHEMBL193996       -1.073472 -0.382930  0.380867  -1.135801 -0.089721
#
#                     nBridgehead   nHetero        nB        nN        nO  ...  \
# molecule_chembl_id                                                       ...
# CHEMBL11805           -0.163233  0.730146 -0.065233  0.955423  0.530488  ...
# CHEMBL208599           5.340041 -1.353464 -0.065233 -0.266690 -1.569221  ...
# CHEMBL60745           -0.163233 -1.353464 -0.065233 -0.877747 -1.044294  ...
# CHEMBL95              -0.163233 -1.770186 -0.065233 -0.266690 -1.569221  ...
# CHEMBL173309          -0.163233  0.730146 -0.065233  0.955423  0.530488  ...
# ...                         ...       ...       ...       ...       ...  ...
# CHEMBL5220695         -0.163233  0.313424 -0.065233  0.344367  0.530488  ...
# CHEMBL5219239         -0.163233  0.313424 -0.065233  0.344367  0.530488  ...
# CHEMBL5218804         -0.163233 -0.936742 -0.065233 -0.877747  0.005561  ...
# CHEMBL5219425          5.340041 -0.520020 -0.065233 -0.266690 -0.519366  ...
# CHEMBL193996           5.340041 -0.936742 -0.065233 -0.266690 -0.519366  ...
#
#                         JGI3      JGI4      JGI5      JGI6      JGI7  \
# molecule_chembl_id
# CHEMBL11805        -0.549645 -0.656709 -0.615962 -0.979284 -0.583657
# CHEMBL208599        0.915764  0.739583  1.129886  0.406215  1.394307
# CHEMBL60745         0.804034  1.265459  1.000292  0.554652 -2.569629
# CHEMBL95            0.231339  1.478972 -0.618365 -0.677716 -2.569629
# CHEMBL173309       -0.728975 -0.859856 -0.837146 -0.882694 -0.591194
# ...                      ...       ...       ...       ...       ...
# CHEMBL5220695       0.999675 -0.840255  0.087875  0.857119  0.201399
# CHEMBL5219239       1.295477 -0.511460  0.200874  0.728633  0.325246
# CHEMBL5218804      -0.686181 -0.160577 -0.221959  0.242935 -0.255752
# CHEMBL5219425       0.430537  0.555944  0.623707  0.627144  1.514427
# CHEMBL193996       -0.738670 -0.451372 -0.859317  0.569150 -1.405396
#
#                         JGI8      JGI9     JGI10  SRW03       pKi
# molecule_chembl_id
# CHEMBL11805        -0.531796 -0.738214  0.179914    0.0  1.870065
# CHEMBL208599        0.120460  1.911806  2.863825    0.0  2.191256
# CHEMBL60745        -2.306414 -1.909838 -1.837927    0.0  1.232467
# CHEMBL95           -2.306414 -1.909838 -1.837927    0.0  0.183211
# CHEMBL173309       -0.356611 -0.630121  0.011761    0.0  0.766107
# ...                      ...       ...       ...    ...       ...
# CHEMBL5220695       1.598277 -0.390424 -0.139805    0.0  0.236450
# CHEMBL5219239       1.532909 -0.150967  0.119500    0.0  0.155751
# CHEMBL5218804      -0.594722 -0.535216 -0.079403    0.0  1.654232
# CHEMBL5219425       0.988169 -1.909838 -1.837927    0.0 -0.545047
# CHEMBL193996       -0.908250 -0.550536 -1.837927    0.0 -0.254794
#
# [472 rows x 397 columns]

# %% [markdown]
# ## Remove descriptors with low variance

# %%
def variance_threshold_selector(data, threshold=0.15):
    selector = VarianceThreshold(threshold)
    selector.fit(data)
    return data[data.columns[selector.get_support(indices=True)]]

# %%
df1 = variance_threshold_selector(df1)

# %%
df1
# Out:
#                          ABC     nAcid     nBase  nAromAtom    nSpiro  \
# molecule_chembl_id
# CHEMBL11805         1.708479 -0.382930  1.753151  -0.193073 -0.089721
# CHEMBL208599       -0.704518 -0.382930 -0.991417  -0.507315 -0.089721
# CHEMBL60745        -1.785873  1.406605  0.380867  -1.135801 -0.089721
# CHEMBL95           -1.371532 -0.382930 -0.991417  -0.507315 -0.089721
# CHEMBL173309        1.867360 -0.382930  1.753151  -0.193073 -0.089721
# ...                      ...       ...       ...        ...       ...
# CHEMBL5220695      -0.234576 -0.382930  0.380867  -1.135801 -0.089721
# CHEMBL5219239      -0.131434 -0.382930  0.380867  -1.135801 -0.089721
# CHEMBL5218804      -0.608953 -0.382930 -0.991417  -0.193073 -0.089721
# CHEMBL5219425      -1.245683  1.406605  0.380867  -2.078529 -0.089721
# CHEMBL193996       -1.073472 -0.382930  0.380867  -1.135801 -0.089721
#
#                     nBridgehead   nHetero        nB        nN        nO  ...  \
# molecule_chembl_id                                                       ...
# CHEMBL11805           -0.163233  0.730146 -0.065233  0.955423  0.530488  ...
# CHEMBL208599           5.340041 -1.353464 -0.065233 -0.266690 -1.569221  ...
# CHEMBL60745           -0.163233 -1.353464 -0.065233 -0.877747 -1.044294  ...
# CHEMBL95              -0.163233 -1.770186 -0.065233 -0.266690 -1.569221  ...
# CHEMBL173309          -0.163233  0.730146 -0.065233  0.955423  0.530488  ...
# ...                         ...       ...       ...       ...       ...  ...
# CHEMBL5220695         -0.163233  0.313424 -0.065233  0.344367  0.530488  ...
# CHEMBL5219239         -0.163233  0.313424 -0.065233  0.344367  0.530488  ...
# CHEMBL5218804         -0.163233 -0.936742 -0.065233 -0.877747  0.005561  ...
# CHEMBL5219425          5.340041 -0.520020 -0.065233 -0.266690 -0.519366  ...
# CHEMBL193996           5.340041 -0.936742 -0.065233 -0.266690 -0.519366  ...
#
#                         JGI2      JGI3      JGI4      JGI5      JGI6  \
# molecule_chembl_id
# CHEMBL11805         0.233026 -0.549645 -0.656709 -0.615962 -0.979284
# CHEMBL208599       -1.026694  0.915764  0.739583  1.129886  0.406215
# CHEMBL60745         2.493112  0.804034  1.265459  1.000292  0.554652
# CHEMBL95            0.023073  0.231339  1.478972 -0.618365 -0.677716
# CHEMBL173309        0.090800 -0.728975 -0.859856 -0.837146 -0.882694
# ...                      ...       ...       ...       ...       ...
# CHEMBL5220695      -0.529436  0.999675 -0.840255  0.087875  0.857119
# CHEMBL5219239       0.233026  1.295477 -0.511460  0.200874  0.728633
# CHEMBL5218804      -0.740394 -0.686181 -0.160577 -0.221959  0.242935
# CHEMBL5219425       1.638099  0.430537  0.555944  0.623707  0.627144
# CHEMBL193996       -1.376616 -0.738670 -0.451372 -0.859317  0.569150
#
#                         JGI7      JGI8      JGI9     JGI10       pKi
# molecule_chembl_id
# CHEMBL11805        -0.583657 -0.531796 -0.738214  0.179914  1.870065
# CHEMBL208599        1.394307  0.120460  1.911806  2.863825  2.191256
# CHEMBL60745        -2.569629 -2.306414 -1.909838 -1.837927  1.232467
# CHEMBL95           -2.569629 -2.306414 -1.909838 -1.837927  0.183211
# CHEMBL173309       -0.591194 -0.356611 -0.630121  0.011761  0.766107
# ...                      ...       ...       ...       ...       ...
# CHEMBL5220695       0.201399  1.598277 -0.390424 -0.139805  0.236450
# CHEMBL5219239       0.325246  1.532909 -0.150967  0.119500  0.155751
# CHEMBL5218804      -0.255752 -0.594722 -0.535216 -0.079403  1.654232
# CHEMBL5219425       1.514427  0.988169 -1.909838 -1.837927 -0.545047
# CHEMBL193996       -1.405396 -0.908250 -0.550536 -1.837927 -0.254794
#
# [472 rows x 236 columns]

# %% [markdown]
# ## More steps

# %%
from sklearn.feature_selection import mutual_info_regression, SelectKBest
from sklearn.metrics import r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df1, y, test_size=0.33, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((316, 236), (156, 236))

# %% [markdown]
# ### First we need to drop coorelated descriptors

# %%
from feature_engine.selection import DropCorrelatedFeatures, SmartCorrelatedSelection
from sklearn.feature_selection import VarianceThreshold, f_regression

# %%
Sel = DropCorrelatedFeatures(threshold= 0.15,
                             method= 'pearson', 
                            missing_values='ignore')
Sel.fit(X_train, y_train)
# Out:
# DropCorrelatedFeatures(threshold=0.15)

# %%
len(Sel.features_to_drop_)
# Out:
# 217

# %%
#y_trainA = Sel.fit_transform(X_trainA)

# %%
X_trainA = Sel.transform(X_train)
X_testA = Sel.transform(X_test)

X_trainA.shape, X_testA.shape
# Out:
# ((316, 19), (156, 19))

# %%
y_trainA = y_train.loc[X_trainA.index]

# %%
y_trainA
# Out:
# molecule_chembl_id
# CHEMBL4292477    7.207608
# CHEMBL3326700    7.404504
# CHEMBL4080726    4.879426
# CHEMBL3326711    7.258061
# CHEMBL4583534    7.000000
#                    ...
# CHEMBL592857     3.508638
# CHEMBL3235217    5.511873
# CHEMBL3819155    5.549443
# CHEMBL4783427    6.404504
# CHEMBL151        4.181774
# Name: pKi, Length: 316, dtype: float64

# %%
select_reg = SelectKBest(f_regression,k=5)
select_reg.fit(X_trainA, y_train)
X_trainB = select_reg.transform(X_trainA)
X_testB = select_reg.transform(X_testA)
# Out:
# /Users/adnane/opt/anaconda3/envs/ADN/lib/python3.7/site-packages/sklearn/feature_selection/_univariate_selection.py:284: RuntimeWarning: invalid value encountered in sqrt
#   X_norms = np.sqrt(row_norms(X.T, squared=True) - n_samples * X_means ** 2)

# %%
X_trainC = X_trainA.iloc[:,select_reg.get_support()]
X_testC = X_testA.iloc[:,select_reg.get_support()]

# %%
X_trainC.shape, X_testC.shape
# Out:
# ((316, 5), (156, 5))

# %%
X_trainC.head(), X_testC.head()
# Out:
# (                         ABC  nBridgehead    ATSC4c    GATS2d  PEOE_VSA13
#  molecule_chembl_id
#  CHEMBL4292477       0.166579    -0.163233 -1.148664  0.384693    1.131203
#  CHEMBL3326700       0.788392    -0.163233  0.660501 -1.190017    1.131203
#  CHEMBL4080726       0.195113    -0.163233 -0.261420 -1.641450   -0.475683
#  CHEMBL3326711       0.976350    -0.163233  1.515439 -1.185167    1.131203
#  CHEMBL4583534      -0.369609    -0.163233 -0.023089  0.451069   -0.475683,
#                           ABC  nBridgehead    ATSC4c    GATS2d  PEOE_VSA13
#  molecule_chembl_id
#  CHEMBL254300       -1.277506    -0.163233  0.557457  2.733309   -0.475683
#  CHEMBL481           1.631985    -0.163233 -0.921737 -0.468875    1.036562
#  CHEMBL1255901      -1.059564     5.340041  0.175167  0.792889   -0.475683
#  CHEMBL3235225      -0.133685    -0.163233  0.034537  1.096678   -0.475683
#  CHEMBL2323355      -0.222289    -0.163233 -0.118543  1.258525    1.131203)

# %%
#£Code from Stackoverflow "Variance Inflation Factor in Python"
# import warnings
# warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
from sklearn.linear_model import LinearRegression

def sklearn_vif(exogs, data):

    # initialize dictionaries
    vif_dict, tolerance_dict = {}, {}

    # form input data for each exogenous variable
    for exog in exogs:
        not_exog = [i for i in exogs if i != exog]
        X, y = data[not_exog], data[exog]

        # extract r-squared from the fit
        r_squared = LinearRegression().fit(X, y).score(X, y)

        # calculate VIF
        vif = 1/(1 - r_squared)
        vif_dict[exog] = vif

        # calculate tolerance
        tolerance = 1 - r_squared
        tolerance_dict[exog] = tolerance

    # return VIF DataFrame
    df_vif = pd.DataFrame({'VIF': vif_dict, 'Tolerance': tolerance_dict})

    return df_vif

# %%
sklearn_vif(X_trainC.columns, X_trainC)
# Out:
#                   VIF  Tolerance
# ABC          1.067244   0.936993
# nBridgehead  1.036082   0.965174
# ATSC4c       1.039978   0.961559
# GATS2d       1.026348   0.974329
# PEOE_VSA13   1.017326   0.982969

# %% [markdown]
# # To be continued...
